# %%
import boto3
import pandas as pd 
import io
import sys
sys.path.append("../")
from src.scripts import extraction as ex
bucket = 'team-yogurt-cleaned-data'
key = '2022/7/20/london_brixton_cleaned_20-07-2022_08-00-00.csv'
s3 = boto3.client('s3',
    aws_access_key_id="ASIASIVOTZVFVSBVRMJX",
    aws_secret_access_key="4XPuw7Q5Wk8prLhR7CcvwKYZuVZ9Q+18rU0XPpan",
    aws_session_token="...")
response= s3.get_object(Bucket=bucket, Key=key)

# %%
file = response['Body']
data = file.read().decode('utf-8')
df = pd.read_csv(io.StringIO(data))

# %%
df = ex.clean_the_data(df)
ex.etl(df)
# Out:
# Customers DF OK
# Location DF OK
# Cards DF OK
# mysql+pymysql://None:None@localhost:3307/None
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 df = ex.clean_the_data(df)
# ----> 2 ex.etl(df)
#
# File ~/Documents/academy/final_project/project_yoghurt/team_repo_3/tests/../src/scripts/extraction.py:244, in etl(df_exploded, get_table_df, insert_names, insert_cards, insert_store, insert_products)
#     234 def etl(
#     235     df_exploded,
#     236     get_table_df=get_table_df,
#    (...)
#     242 ):
#     243     # generate our dataframes
# --> 244     customer_df, location_df, cards_df, products_df = get_table_df(df_exploded)
#     246     # clean our product data
#     247     # each of these executes a series of sql commands to insert the data into our database
#     249     insert_names(customer_df)
#
# ...
